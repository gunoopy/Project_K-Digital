# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14751, done.
# remote: Total 14751 (delta 0), reused 0 (delta 0), pack-reused 14751
# Receiving objects: 100% (14751/14751), 13.28 MiB | 16.23 MiB/s, done.
# Resolving deltas: 100% (10029/10029), done.

# %%
# %cd /content/darknet/
# Out:
# /content/darknet

# %% [markdown]
# Makefile 수정

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !unzip "/content/drive/My Drive/darknet.zip"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: data/img/S07E02_00002080.jpg
#   inflating: data/img/S07E02_00002080.txt
#   inflating: data/img/S07E02_00002081.jpg
#   inflating: data/img/S07E02_00002081.txt
#   inflating: data/img/S07E02_00002083.jpg
#   inflating: data/img/S07E02_00002083.txt
#   inflating: data/img/S07E02_00002084.jpg
#   inflating: data/img/S07E02_00002084.txt
#   inflating: data/img/S07E02_00002085.jpg
#   inflating: data/img/S07E02_00002085.txt
#   inflating: data/img/S07E02_00002088.jpg
#   inflating: data/img/S07E02_00002088.txt
#   inflating: data/img/S07E02_00002090.jpg
#   inflating: data/img/S07E02_00002090.txt
#   inflating: data/img/S07E02_00002094.jpg
#   inflating: data/img/S07E02_00002094.txt
#   inflating: data/img/S07E02_00002178.jpg
#   inflating: data/img/S07E02_00002178.txt
#   inflating: data/img/S07E02_00002338.jpg
#   inflating: data/img/S07E02_00002338.txt
#   inflating: data/img/S07E02_00002416.jpg
# ...

# %%
# %cp ./darknet /content/drive/My\ Drive/darknet

# %%
# !chmod +x ./darknet

# %%
# !./darknet detector
# Out:
# CUDA status Error: file: ./src/dark_cuda.c : () : line: 39 : build time: Apr 14 2021 - 13:49:25
#
#  CUDA Error: no CUDA-capable device is detected
# CUDA Error: no CUDA-capable device is detected: Bad file descriptor
# darknet: ./src/utils.c:331: error: Assertion `0' failed.

# %%
#!rm /content/darknet/backup -r
#!ln -s /content/drive/'My Drive'/backup /content/darknet

# %%
# %%time
# !./darknet detector train data/yolo.data cfg/yolov3_custom_train.cfg darknet53.conv.74 -map -dont_show log.txt
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.311228), count: 1, class_loss = 2093.471680, iou_loss = 0.908203, total_loss = 2094.379883
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 6236.620117, iou_loss = 0.000000, total_loss = 6236.620117
#  total_bbox = 2732, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.304801), count: 4, class_loss = 450.899261, iou_loss = 5.113678, total_loss = 456.012939
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.345935), count: 10, class_loss = 2099.624023, iou_loss = 9.210938, total_loss = 2108.834961
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 6244.598633, iou_loss = 0.000000, total_loss = 6244.598633
# ...
