# %% [markdown]
# ### import packages

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.4.1'

# %%
import keras
keras.__version__
# Out:
# '2.4.3'

# %%
# !nvidia-smi
# Out:
# Fri Apr 23 05:40:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Load Data

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -l '/content/drive/MyDrive/인공지능 프로젝트/data/image'
# Out:
# total 2660014
# -rw------- 1 root root 513436900 Apr 23 00:49  capture_data.zip
# drwx------ 2 root root      4096 Apr 14 07:56 'classified image'
# -rw------- 1 root root 540381379 Apr 23 00:49  crop_data.zip
# drwx------ 2 root root      4096 Apr  7 07:27 'crop image'
# -rw------- 1 root root 515295898 Apr 19 01:49 'data_All(cap).zip'
# -rw------- 1 root root 540218524 Apr 18 13:31 'data_All(crop).zip'
# drwx------ 2 root root      4096 Apr 12 00:22 'mark yolo'
# -rw------- 1 root root 187132360 Apr 19 00:00 'test(googleClear).zip'
# drwx------ 2 root root      4096 Apr 13 01:49 'test image'
# -rw------- 1 root root 127936660 Apr 12 05:25 'walking dead_s09e04(modified).zip'
# -rw------- 1 root root 292564196 Apr  8 01:35 'walking dead_s09e05.zip'
# -rw------- 1 root root   4570216 Apr  6 01:38 'zombie2(walking dead_google).zip'
# -rw------- 1 root root   2298382 Apr  5 08:13 'zombie(walking dead_google).zip'

# %%
# !unzip '/content/drive/MyDrive/인공지능 프로젝트/data/image/data_All(cap).zip'
# Out:
# Archive:  /content/drive/MyDrive/인공지능 프로젝트/data/image/data_All(cap).zip
#   inflating: data/test/human/human_google_0000001 (10).jpg
#   inflating: data/test/human/human_google_0000001 (100).jpg
#  extracting: data/test/human/human_google_0000001 (101).jpg
#   inflating: data/test/human/human_google_0000001 (102).jpg
#   inflating: data/test/human/human_google_0000001 (103).jpg
#   inflating: data/test/human/human_google_0000001 (104).jpg
#  extracting: data/test/human/human_google_0000001 (105).jpg
#   inflating: data/test/human/human_google_0000001 (106).jpg
#  extracting: data/test/human/human_google_0000001 (107).jpg
#   inflating: data/test/human/human_google_0000001 (108).jpg
#   inflating: data/test/human/human_google_0000001 (109).jpg
#   inflating: data/test/human/human_google_0000001 (11).jpg
#   inflating: data/test/human/human_google_0000001 (110).jpg
#   inflating: data/test/human/human_google_0000001 (111).jpg
#   inflating: data/test/human/human_google_0000001 (112).jpg
#   inflating: data/test/human/human_google_0000001 (113).jpg
#   inflating: data/test/human/human_google_0000001 (114).jpg
#   inflating: data/test/human/human_google_0000001 (115).jpg
#   inflating: data/test/human/human_google_0000001 (116).jpg
#   inflating: data/test/human/human_google_0000001 (117).jpg
#   inflating: data/test/human/human_google_0000001 (118).jpg
#  extracting: data/test/human/human_google_0000001 (119).jpg
#   inflating: data/test/human/human_google_0000001 (12).jpg
#   inflating: data/test/human/human_google_0000001 (120).jpg
#   inflating: data/test/human/human_google_0000001 (121).jpg
#   inflating: data/test/human/human_google_0000001 (122).jpg
#   inflating: data/test/human/human_google_0000001 (123).jpg
#   inflating: data/test/human/human_google_0000001 (124).jpg
#   inflating: data/test/human/human_google_0000001 (125).jpg
#  extracting: data/test/human/human_google_0000001 (126).jpg
#  extracting: data/test/human/human_google_0000001 (127).jpg
#   inflating: data/test/human/human_google_0000001 (128).jpg
#  extracting: data/test/human/human_google_0000001 (129).jpg
#   inflating: data/test/human/human_google_0000001 (13).jpg
#   inflating: data/test/human/human_google_0000001 (130).jpg
#   inflating: data/test/human/human_google_0000001 (131).jpg
#   inflating: data/test/human/human_google_0000001 (132).jpg
#   inflating: data/test/human/human_google_0000001 (133).jpg
#  extracting: data/test/human/human_google_0000001 (134).jpg
#   inflating: data/test/human/human_google_0000001 (135).jpg
#   inflating: data/test/human/human_google_0000001 (136).jpg
#   inflating: data/test/human/human_google_0000001 (137).jpg
#   inflating: data/test/human/human_google_0000001 (138).jpg
#   inflating: data/test/human/human_google_0000001 (139).jpg
#   inflating: data/test/human/human_google_0000001 (14).jpg
#   inflating: data/test/human/human_google_0000001 (140).jpg
#  extracting: data/test/human/human_google_0000001 (141).jpg
#   inflating: data/test/human/human_google_0000001 (142).jpg
#   inflating: data/test/human/human_google_0000001 (143).jpg
#   inflating: data/test/human/human_google_0000001 (144).jpg
#  extracting: data/test/human/human_google_0000001 (145).jpg
#   inflating: data/test/human/human_google_0000001 (146).jpg
#   inflating: data/test/human/human_google_0000001 (147).jpg
#   inflating: data/test/human/human_google_0000001 (148).jpg
#   inflating: data/test/human/human_google_0000001 (149).jpg
#   inflating: data/test/human/human_google_0000001 (15).jpg
#  extracting: data/test/human/human_google_0000001 (150).jpg
#   inflating: data/test/human/human_google_0000001 (151).jpg
#  extracting: data/test/human/human_google_0000001 (152).jpg
#  extracting: data/test/human/human_google_0000001 (153).jpg
#   inflating: data/test/human/human_google_0000001 (154).jpg
#   inflating: data/test/human/human_google_0000001 (155).jpg
#   inflating: data/test/human/human_google_0000001 (156).jpg
#   inflating: data/test/human/human_google_0000001 (157).jpg
#   inflating: data/test/human/human_google_0000001 (158).jpg
#   inflating: data/test/human/human_google_0000001 (159).jpg
#  extracting: data/test/human/human_google_0000001 (16).jpg
#   inflating: data/test/human/human_google_0000001 (160).jpg
#   inflating: data/test/human/human_google_0000001 (161).jpg
#   inflating: data/test/human/human_google_0000001 (162).jpg
#   inflating: data/test/human/human_google_0000001 (163).jpg
#   inflating: data/test/human/human_google_0000001 (164).jpg
#   inflating: data/test/human/human_google_0000001 (165).jpg
#   inflating: data/test/human/human_google_0000001 (166).jpg
#   inflating: data/test/human/human_google_0000001 (167).jpg
#  extracting: data/test/human/human_google_0000001 (168).jpg
#   inflating: data/test/human/human_google_0000001 (169).jpg
#   inflating: data/test/human/human_google_0000001 (17).jpg
#   inflating: data/test/human/human_google_0000001 (170).jpg
#   inflating: data/test/human/human_google_0000001 (171).jpg
#   inflating: data/test/human/human_google_0000001 (172).jpg
#   inflating: data/test/human/human_google_0000001 (173).jpg
#   inflating: data/test/human/human_google_0000001 (174).jpg
#  extracting: data/test/human/human_google_0000001 (175).jpg
#   inflating: data/test/human/human_google_0000001 (176).jpg
#  extracting: data/test/human/human_google_0000001 (177).jpg
#   inflating: data/test/human/human_google_0000001 (178).jpg
#   inflating: data/test/human/human_google_0000001 (179).jpg
#   inflating: data/test/human/human_google_0000001 (18).jpg
#   inflating: data/test/human/human_google_0000001 (180).jpg
#   inflating: data/test/human/human_google_0000001 (181).jpg
#   inflating: data/test/human/human_google_0000001 (182).jpg
#   inflating: data/test/human/human_google_0000001 (183).jpg
#   inflating: data/test/human/human_google_0000001 (184).jpg
#   inflating: data/test/human/human_google_0000001 (185).jpg
#  extracting: data/test/human/human_google_0000001 (186).jpg
#   inflating: data/test/human/human_google_0000001 (187).jpg
#   inflating: data/test/human/human_google_0000001 (188).jpg
#   inflating: data/test/human/human_google_0000001 (189).jpg
#   inflating: data/test/human/human_google_0000001 (19).jpg
#   inflating: data/test/human/human_google_0000001 (190).jpg
#  extracting: data/test/human/human_google_0000001 (191).jpg
#   inflating: data/test/human/human_google_0000001 (192).jpg
#   inflating: data/test/human/human_google_0000001 (193).jpg
#   inflating: data/test/human/human_google_0000001 (194).jpg
#  extracting: data/test/human/human_google_0000001 (195).jpg
#   inflating: data/test/human/human_google_0000001 (196).jpg
#   inflating: data/test/human/human_google_0000001 (198).jpg
#   inflating: data/test/human/human_google_0000001 (199).jpg
#   inflating: data/test/human/human_google_0000001 (2).jpg
#   inflating: data/test/human/human_google_0000001 (20).jpg
#  extracting: data/test/human/human_google_0000001 (200).jpg
#   inflating: data/test/human/human_google_0000001 (201).jpg
#   inflating: data/test/human/human_google_0000001 (202).jpg
#   inflating: data/test/human/human_google_0000001 (203).jpg
#   inflating: data/test/human/human_google_0000001 (204).jpg
#   inflating: data/test/human/human_google_0000001 (205).jpg
#   inflating: data/test/human/human_google_0000001 (206).jpg
#  extracting: data/test/human/human_google_0000001 (207).jpg
#   inflating: data/test/human/human_google_0000001 (208).jpg
#   inflating: data/test/human/human_google_0000001 (209).jpg
#   inflating: data/test/human/human_google_0000001 (21).jpg
#  extracting: data/test/human/human_google_0000001 (210).jpg
#   inflating: data/test/human/human_google_0000001 (211).jpg
#   inflating: data/test/human/human_google_0000001 (212).jpg
#   inflating: data/test/human/human_google_0000001 (213).jpg
#  extracting: data/test/human/human_google_0000001 (214).jpg
#   inflating: data/test/human/human_google_0000001 (215).jpg
#   inflating: data/test/human/human_google_0000001 (216).jpg
#  extracting: data/test/human/human_google_0000001 (217).jpg
#   inflating: data/test/human/human_google_0000001 (218).jpg
#  extracting: data/test/human/human_google_0000001 (219).jpg
#  extracting: data/test/human/human_google_0000001 (22).jpg
#   inflating: data/test/human/human_google_0000001 (220).jpg
#   inflating: data/test/human/human_google_0000001 (221).jpg
#   inflating: data/test/human/human_google_0000001 (222).jpg
#   inflating: data/test/human/human_google_0000001 (223).jpg
#   inflating: data/test/human/human_google_0000001 (224).jpg
#   inflating: data/test/human/human_google_0000001 (225).jpg
#   inflating: data/test/human/human_google_0000001 (226).jpg
#  extracting: data/test/human/human_google_0000001 (227).jpg
#   inflating: data/test/human/human_google_0000001 (228).jpg
#   inflating: data/test/human/human_google_0000001 (229).jpg
#   inflating: data/test/human/human_google_0000001 (23).jpg
#  extracting: data/test/human/human_google_0000001 (230).jpg
#   inflating: data/test/human/human_google_0000001 (231).jpg
#   inflating: data/test/human/human_google_0000001 (232).jpg
#   inflating: data/test/human/human_google_0000001 (233).jpg
#   inflating: data/test/human/human_google_0000001 (234).jpg
#   inflating: data/test/human/human_google_0000001 (24).jpg
#   inflating: data/test/human/human_google_0000001 (25).jpg
#  extracting: data/test/human/human_google_0000001 (26).jpg
#   inflating: data/test/human/human_google_0000001 (27).jpg
#   inflating: data/test/human/human_google_0000001 (28).jpg
#   inflating: data/test/human/human_google_0000001 (29).jpg
#  extracting: data/test/human/human_google_0000001 (30).jpg
#   inflating: data/test/human/human_google_0000001 (31).jpg
#   inflating: data/test/human/human_google_0000001 (32).jpg
#   inflating: data/test/human/human_google_0000001 (33).jpg
#  extracting: data/test/human/human_google_0000001 (34).jpg
#   inflating: data/test/human/human_google_0000001 (35).jpg
#  extracting: data/test/human/human_google_0000001 (36).jpg
#   inflating: data/test/human/human_google_0000001 (37).jpg
#  extracting: data/test/human/human_google_0000001 (38).jpg
#   inflating: data/test/human/human_google_0000001 (39).jpg
#   inflating: data/test/human/human_google_0000001 (4).jpg
#   inflating: data/test/human/human_google_0000001 (40).jpg
#  extracting: data/test/human/human_google_0000001 (41).jpg
#  extracting: data/test/human/human_google_0000001 (42).jpg
#  extracting: data/test/human/human_google_0000001 (43).jpg
#   inflating: data/test/human/human_google_0000001 (44).jpg
#   inflating: data/test/human/human_google_0000001 (45).jpg
#   inflating: data/test/human/human_google_0000001 (46).jpg
#   inflating: data/test/human/human_google_0000001 (47).jpg
#  extracting: data/test/human/human_google_0000001 (48).jpg
#   inflating: data/test/human/human_google_0000001 (49).jpg
#   inflating: data/test/human/human_google_0000001 (5).jpg
#   inflating: data/test/human/human_google_0000001 (50).jpg
#   inflating: data/test/human/human_google_0000001 (51).jpg
#   inflating: data/test/human/human_google_0000001 (52).jpg
#   inflating: data/test/human/human_google_0000001 (53).jpg
#   inflating: data/test/human/human_google_0000001 (54).jpg
#  extracting: data/test/human/human_google_0000001 (55).jpg
#   inflating: data/test/human/human_google_0000001 (56).jpg
#  extracting: data/test/human/human_google_0000001 (57).jpg
#   inflating: data/test/human/human_google_0000001 (58).jpg
#  extracting: data/test/human/human_google_0000001 (59).jpg
#   inflating: data/test/human/human_google_0000001 (6).jpg
#   inflating: data/test/human/human_google_0000001 (60).jpg
#  extracting: data/test/human/human_google_0000001 (61).jpg
#   inflating: data/test/human/human_google_0000001 (62).jpg
#  extracting: data/test/human/human_google_0000001 (63).jpg
#   inflating: data/test/human/human_google_0000001 (64).jpg
#  extracting: data/test/human/human_google_0000001 (65).jpg
#   inflating: data/test/human/human_google_0000001 (66).jpg
#   inflating: data/test/human/human_google_0000001 (67).jpg
#  extracting: data/test/human/human_google_0000001 (68).jpg
#  extracting: data/test/human/human_google_0000001 (69).jpg
#   inflating: data/test/human/human_google_0000001 (7).jpg
#  extracting: data/test/human/human_google_0000001 (70).jpg
#   inflating: data/test/human/human_google_0000001 (71).jpg
#   inflating: data/test/human/human_google_0000001 (72).jpg
#   inflating: data/test/human/human_google_0000001 (73).jpg
#   inflating: data/test/human/human_google_0000001 (75).jpg
#   inflating: data/test/human/human_google_0000001 (76).jpg
#   inflating: data/test/human/human_google_0000001 (77).jpg
#   inflating: data/test/human/human_google_0000001 (78).jpg
#   inflating: data/test/human/human_google_0000001 (79).jpg
#   inflating: data/test/human/human_google_0000001 (8).jpg
#  extracting: data/test/human/human_google_0000001 (80).jpg
#  extracting: data/test/human/human_google_0000001 (81).jpg
#   inflating: data/test/human/human_google_0000001 (82).jpg
#  extracting: data/test/human/human_google_0000001 (83).jpg
#   inflating: data/test/human/human_google_0000001 (84).jpg
#   inflating: data/test/human/human_google_0000001 (85).jpg
#   inflating: data/test/human/human_google_0000001 (86).jpg
#   inflating: data/test/human/human_google_0000001 (87).jpg
#   inflating: data/test/human/human_google_0000001 (88).jpg
#   inflating: data/test/human/human_google_0000001 (89).jpg
#   inflating: data/test/human/human_google_0000001 (9).jpg
#   inflating: data/test/human/human_google_0000001 (90).jpg
#   inflating: data/test/human/human_google_0000001 (91).jpg
#   inflating: data/test/human/human_google_0000001 (92).jpg
#   inflating: data/test/human/human_google_0000001 (93).jpg
#   inflating: data/test/human/human_google_0000001 (94).jpg
#   inflating: data/test/human/human_google_0000001 (95).jpg
#   inflating: data/test/human/human_google_0000001 (96).jpg
#   inflating: data/test/human/human_google_0000001 (97).jpg
#   inflating: data/test/human/human_google_0000001 (98).jpg
#   inflating: data/test/human/human_google_0000001 (99).jpg
#   inflating: data/test/human/human_google_0000001.jpg
#   inflating: data/test/human/human_google_0000003.jpg
#   inflating: data/test/zombie/zombie (1).jpg
#   inflating: data/test/zombie/zombie (10).jpg
#   inflating: data/test/zombie/zombie (11).jpg
#   inflating: data/test/zombie/zombie (12).jpg
#   inflating: data/test/zombie/zombie (13).jpg
#   inflating: data/test/zombie/zombie (14).jpg
#   inflating: data/test/zombie/zombie (15).jpg
#   inflating: data/test/zombie/zombie (16).jpg
#   inflating: data/test/zombie/zombie (17).jpg
#   inflating: data/test/zombie/zombie (18).jpg
#   inflating: data/test/zombie/zombie (19).jpg
#   inflating: data/test/zombie/zombie (2).jpg
#   inflating: data/test/zombie/zombie (22).jpg
#  extracting: data/test/zombie/zombie (23).jpg
#   inflating: data/test/zombie/zombie (24).jpg
#  extracting: data/test/zombie/zombie (25).jpg
#   inflating: data/test/zombie/zombie (26).jpg
#   inflating: data/test/zombie/zombie (27).jpg
#   inflating: data/test/zombie/zombie (28).jpg
#   inflating: data/test/zombie/zombie (29).jpg
#  extracting: data/test/zombie/zombie (3).jpg
#   inflating: data/test/zombie/zombie (30).jpg
#  extracting: data/test/zombie/zombie (31).jpg
#   inflating: data/valid/zombie/S09E05_00004141.jpg
#   inflating: data/valid/zombie/S09E05_00004153.jpg
#   inflating: data/valid/zombie/S09E05_00004603.jpg
#   inflating: data/valid/zombie/S09E05_00004604.jpg
#   inflating: data/valid/zombie/S09E05_00004633.jpg
#   inflating: data/valid/zombie/S09E05_00004635.jpg
#   inflating: data/valid/zombie/S09E05_00004683.jpg
#   inflating: data/valid/zombie/S09E05_00004695.jpg
#   inflating: data/valid/zombie/S09E05_00004696.jpg
#   inflating: data/valid/zombie/S09E05_00004697.jpg
#   inflating: data/valid/zombie/S09E05_00004698.jpg
#   inflating: data/valid/zombie/S09E05_00004699.jpg
#   inflating: data/valid/zombie/S09E05_00004700.jpg
#   inflating: data/valid/zombie/S09E05_00004701.jpg
#   inflating: data/valid/zombie/S09E05_00004702.jpg
#   inflating: data/valid/zombie/S09E05_00004721.jpg
#   inflating: data/valid/zombie/S09E05_00004723.jpg
#   inflating: data/valid/zombie/S09E05_00004724.jpg
#   inflating: data/valid/zombie/S09E05_00004874.jpg
#   inflating: data/valid/zombie/S09E05_00004908.jpg
#   inflating: data/valid/zombie/S09E05_00004914.jpg
#   inflating: data/valid/zombie/S09E05_00004926.jpg
#   inflating: data/valid/zombie/S09E05_00004927.jpg
#   inflating: data/valid/zombie/S09E05_00004928.jpg
#   inflating: data/valid/zombie/S09E05_00004943.jpg
#   inflating: data/valid/zombie/S09E05_00004944.jpg
#   inflating: data/valid/zombie/S09E05_00004945.jpg
#   inflating: data/valid/zombie/S09E05_00004946.jpg
#   inflating: data/valid/zombie/S09E05_00004947.jpg
#   inflating: data/valid/zombie/S09E05_00004948.jpg
#   inflating: data/valid/zombie/S09E05_00004949.jpg
#   inflating: data/valid/zombie/S09E05_00004950.jpg
#   inflating: data/valid/zombie/S09E05_00004951.jpg
#   inflating: data/valid/zombie/S09E05_00004970.jpg
#   inflating: data/valid/zombie/S09E05_00004972.jpg
#   inflating: data/valid/zombie/S09E05_00005656.jpg
#   inflating: data/valid/zombie/S09E05_00005752.jpg
#   inflating: data/valid/zombie/S09E05_00005753.jpg
#   inflating: data/valid/zombie/S09E06_00000462.jpg
#   inflating: data/valid/zombie/S09E06_00000463.jpg
#   inflating: data/valid/zombie/S09E06_00005048.jpg
#   inflating: data/valid/zombie/S09E06_00006986.jpg
#   inflating: data/valid/zombie/S09E06_00006987.jpg

# %% [markdown]
# ## jpg 변환

# %%
# -----------------------
#  change directory name
# -----------------------

data_root_dir = 'data'
os.listdir(data_root_dir)
# Out:
# ['valid', 'test', 'train']

# %%
# -----------------------
#  change directory name
# -----------------------
dir_names = [data_root_dir + child for child in ['/train/human', '/train/zombie',  '/valid/human', '/valid/zombie', '/test/human', '/test/zombie']]


# 확장자 명 정규 표현식
p = re.compile('(.*)[.].*$')


for dir_name in dir_names :
    for file_name in os.listdir(dir_name) :
        if '.' in file_name : # only files (Not directory)
            os.rename(f'{dir_name}/{file_name}', f'{dir_name}/{p.search(file_name).group(1) + ".jpg"}')

# %%
# 확장자 명 확인
os.listdir(data_root_dir + '/train/human')[:5]
# Out:
# ['S09E15_00002773.jpg',
#  'S09E07_00001759.jpg',
#  'S07E04_00000268.jpg',
#  'S07E05_00000016.jpg',
#  'S09E09_00005731.jpg']

# %%
train_dir = data_root_dir + '/train'
valid_dir = data_root_dir + '/valid'
test_dir = data_root_dir + '/test'


print(f'- Train Directory : {train_dir}')
print(f'- Validation Directory : {valid_dir}')
print(f'- Test Directory  : {test_dir}')
# Out:
# - Train Directory : data/train
# - Validation Directory : data/valid
# - Test Directory  : data/test

# %%
train_human_dir = train_dir + '/human'
train_zombie_dir = train_dir + '/zombie'
valid_human_dir = valid_dir + '/human'
valid_zombie_dir = valid_dir + '/zombie'
test_human_dir = test_dir + '/human'
test_zombie_dir = test_dir + '/zombie'

print('* Train Human Data')
print(f'==> {len(os.listdir(train_human_dir))}')

print('\n* Train Zombie Data')
print(f'==> {len(os.listdir(train_zombie_dir))}')

print('\n* Validation Human Data')
print(f'==> {len(os.listdir(valid_human_dir))}')

print('\n* validation Zombie Data')
print(f'==> {len(os.listdir(valid_zombie_dir))}')

print('\n* Test Human Data')
print(f'==> {len(os.listdir(test_human_dir))}')

print('\n* Test Zombie Data')
print(f'==> {len(os.listdir(test_zombie_dir))}')
# Out:
# * Train Human Data
# ==> 902
#
# * Train Zombie Data
# ==> 485
#
# * Validation Human Data
# ==> 538
#
# * validation Zombie Data
# ==> 199
#
# * Test Human Data
# ==> 232
#
# * Test Zombie Data
# ==> 54

# %% [markdown]
# ## Generate Data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(rescale = 1./255,)

valid_gen = ImageDataGenerator(rescale = 1./255)

test_gen = ImageDataGenerator(rescale = 1./255)


train_data = train_gen.flow_from_directory(train_dir,
                                           target_size = (200,200), 
                                           batch_size = 20,
                                           class_mode = 'binary')

valid_data = valid_gen.flow_from_directory(valid_dir,
                                         target_size = (200,200),
                                         batch_size = 20,
                                         shuffle = False,
                                         class_mode = 'binary')

test_data = test_gen.flow_from_directory(test_dir,
                                         target_size = (200,200),
                                         batch_size = 20,
                                         shuffle = False,
                                         class_mode = 'binary')
# Out:
# Found 1387 images belonging to 2 classes.
# Found 737 images belonging to 2 classes.
# Found 286 images belonging to 2 classes.

# %%
print(f'- Train data : {len(train_data)} batches')
print(f'- Valid data  : {len(valid_data)} batches')
print(f'- Test data  : {len(test_data)} batches')
# Out:
# - Train data : 70 batches
# - Valid data  : 37 batches
# - Test data  : 15 batches

# %%
images = train_data[0][0][:9]
labels = train_data[0][1][:9]

plt.figure(figsize = (10,10))

for i in range(9) :
    plt.subplot(3,3,i+1)
    plt.imshow(images[i])
    plt.title(labels[i])
    plt.axis(False)

plt.show()

# %% [markdown]
# ***
# <br><br><br><br>
# ***

# %% [markdown]
# # Functions

# %% [markdown]
# ## Plot Function

# %%
def plot_score(hist) :
    plt.figure(figsize = (16,12))

    plt.subplot(2,2,1)
    plt.plot(hist.epoch, hist.history['loss'], label = 'Train')
    plt.plot(hist.epoch, hist.history['val_loss'], label = 'Valid')
    plt.grid()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train & Valid Loss')
    plt.axhline(0.2, color = 'red', linewidth = 1, linestyle = '--')
    plt.legend()

    plt.subplot(2,2,2)
    plt.plot(hist.epoch, hist.history['accuracy'], label = 'Train')
    plt.plot(hist.epoch, hist.history['val_accuracy'], label = 'Valid')
    plt.grid()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train & Valid Accuracy')
    plt.axhline(0.9, color = 'red', linewidth = 1, linestyle = '--')
    plt.legend()


    plt.subplot(2,2,3)
    plt.plot(hist.epoch, hist.history['recall'], label = 'Train')
    plt.plot(hist.epoch, hist.history['val_recall'], label = 'Valid')
    plt.grid()
    plt.xlabel('Epochs')
    plt.ylabel('Recall')
    plt.title('Train & Valid Recall')
    plt.axhline(0.9, color = 'red', linewidth = 1, linestyle = '--')
    plt.legend()

    plt.subplot(2,2,4)
    plt.plot(hist.epoch, hist.history['precision'], label = 'Train')
    plt.plot(hist.epoch, hist.history['val_precision'], label = 'Valid')
    plt.grid()
    plt.xlabel('Epochs')
    plt.ylabel('Precision')
    plt.title('Train & Valid Precision')
    plt.axhline(0.9, color = 'red', linewidth = 1, linestyle = '--')
    plt.legend()

    plt.show()

# %% [markdown]
# ## Score Function

# %%
def print_score(model, test_data) :
    loss, acc, recall, precision = model.evaluate(test_data)

    print('\n')
    print('*'*16)
    print('*  Evaluation  *')
    print('*'*16)

    print('\n* Loss')
    print(f'==> {loss:.5f}')

    print('\n* Accuracy')
    print(f'==> {acc:.5f}')

    print('\n* Recall')
    print(f'==> {recall:.5f}')

    print('\n* Precision')
    print(f'==> {precision:.5f}')

# %% [markdown]
# ## Wrong Image Function

# %%
def wrong_plot(wrong_idx, pred, test_data) :
    pass

def wrong_img(model, test_data) :
    pred = model.predict_classes(test_data).flatten()
    wrong_bool = (pred != test_data.labels)
    wrong_idx = np.where(wrong_bool)[0]
    

    if len(wrong_idx) >= 9 : # 틀린 개수 9개 이상 => 9개 plot
        check_idx = np.random.choice(wrong_idx, 9, replace = False) # 틀린 9개 비복원 추출
        print(f'\n* CHECK INDEX : {check_idx}\n')
        
        plt.figure(figsize = (16,16))
        for i, idx in enumerate(check_idx) :
            plt.subplot(3,3,i+1)
            plt.imshow(test_data[idx][0][0])
            plt.title(f'Real : {test_data[idx][1][0]}\nPred : {pred[idx]}')
            plt.axis(False)
            
        plt.show()
    elif len(wrong_idx) >= 4 : # 틀린 개수 4개 이상 => 4개 plot
        check_idx = np.random.choice(wrong_idx, 4, replace = False) # 틀린 9개 비복원 추출
        print(f'\n* CHECK INDEX : {check_idx}\n')
        
        plt.figure(figsize = (10,10))
        for i, idx in enumerate(check_idx) :
            plt.subplot(2,2,i+1)
            plt.imshow(test_data[idx][0][0])
            plt.title(f'Real : {test_data[idx][1][0]}\nPred : {pred[idx]}')
            plt.axis(False)
            
        plt.show()
    elif len(wrong_idx) >= 1 : # 틀린 개수 4개 미만 => 1개 plot
        check_idx = np.random.choice(wrong_idx, 1, replace = False) # 틀린 9개 비복원 추출
        print(f'\n* CHECK INDEX : {check_idx}\n')
        
        plt.figure(figsize = (10,10))
        for i, idx in enumerate(check_idx) :
            plt.subplot(1,1,i+1)
            plt.imshow(test_data[idx][0][0])
            plt.title(f'Real : {test_data[idx][1][0]}\nPred : {pred[idx]}')
            plt.axis(False)
            
        plt.show()
    else : print('All Correct!!')

# %% [markdown]
# ## Plot Image Function

# %%
def plot_img(model, data, CHECK_NUM = 3) :
    '''
    CHECK_NUM : plot할 data sample 개수
    '''

    BATCH_SIZE = data.batch_size

    # 예외 처리
    if data.n < CHECK_NUM :
        print(f'Get {data.n} Data. Must be more than {CHECK_NUM}.')
        return 0
    

    # pred  : 1(zombie)일 확률
    # pred0 : 0(human)일 확률
    pred = model.predict(data).flatten()
    pred0 = 1 - pred

    # plot할 sample을 CHECK_NUM 만큼 비복원 추출
    check_idx = np.random.choice(range(data.n), CHECK_NUM, replace = False)
    label_name = {0 : 'Human', 1 : 'Zombie'}

    print(f'* CHECK INDEX : {check_idx}')


    plt.figure(figsize = (14, CHECK_NUM * 5))
    for i, idx in enumerate(check_idx) :

        # image plot
        plt.subplot(CHECK_NUM, 2, 1 + 2*i)
        plt.imshow(data[idx // BATCH_SIZE][0][idx % BATCH_SIZE])
        plt.title(f'real : {data[idx // BATCH_SIZE][1][idx % BATCH_SIZE]}\npred : {pred[idx]:.3f}')
        plt.axis(False)


        # bar plot
        plt.subplot(CHECK_NUM, 2, 2 + 2*i)

        # 0(human)일 확률, 1(zombie)일 확률
        prob = [pred0[idx], pred[idx]]
        plt.barh([0,1], prob, align = 'center', height = 0.5, color = ['c', 'red'],
                        tick_label = ['Human', 'Zombie'], alpha = 0.5)


        # 확률 값 plot
        for i in range(2) :
            if prob[i] > 0.2 :
                plt.text(prob[i] - 0.03, i, f'{prob[i]:.3f}', fontsize = 12, ha='right', va='center')
            else :
                plt.text(prob[i] + 0.03, i, f'{prob[i]:.3f}', fontsize = 12, ha='left', va='center')


        plt.xlim(0,1)
        plt.ylim(-0.8, 1.8)
        plt.title(f'Predict to {label_name[round(pred[idx])]}')
        # plt.xlabel('Probability')


    plt.show()

# %% [markdown]
# ***
# <br><br><br><br>
# ***

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Vanilla CNN
# #### - Data  images(non crop)
# - Train
#     - Season7
#         - Ep4\~16
#     - Season9
#         - Ep1\~9, Ep13
#     - Google
# - Valid
#     - Season7
#         - Ep1\~3
#     - Season9
#         - Ep10\~12, Ep14\~16
# - Test
#     - Google Image
#
# - Augmentation
#     - rotation_range=90
#     - horizontal_flip = True
#     - vertical_flip = True
#
# #### - Layer
# - Input shape : (400,400,3)
# - activation : ReLU
#     - Output shape : (12,12,512)
#
# #### - Compile
# - optimizer : adam
# - learning rate : 0.0001
#
# #### - Fit
# - Ealry stopping / Model Checkpoint
#     - monitor : val_loss
#     - patience : 50
# - class_weight = None

# %%
##Model define 
 
from keras import layers 
from keras import models

#CNN
model = models.Sequential() 
model.add(layers.Conv2D(32, kernel_size= (5, 5), padding = 'same', input_shape = (200, 200, 3)))
#model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
#model.add(layers.Dropout(0.25)) 
model.add(layers.MaxPooling2D((2, 2))) 
model.add(layers.Conv2D(64, (3, 3), padding = 'same'))
#model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
#model.add(layers.Dropout(0.25)) 
model.add(layers.MaxPooling2D((2, 2))) 
model.add(layers.Conv2D(128, (3, 3), padding = 'same'))
#model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
#model.add(layers.Dropout(0.25)) 
model.add(layers.MaxPooling2D((2, 2))) 
model.add(layers.Conv2D(256, (3, 3), padding = 'same'))
#model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.25)) 
model.add(layers.MaxPooling2D((2, 2)))

#DNN
model.add(layers.Flatten()) 
model.add(layers.Dense(256, activation = 'relu')) 
model.add(layers.Dropout(0.5)) 
model.add(layers.Dense(1, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 200, 200, 32)      2432
# _________________________________________________________________
# activation (Activation)      (None, 200, 200, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 100, 100, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 64)      18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 100, 100, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 50, 50, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 256)       295168
# _________________________________________________________________
# activation_3 (Activation)    (None, 25, 25, 256)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 25, 25, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               9437440
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 9,827,649
# Trainable params: 9,827,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers

model.compile(loss = 'binary_crossentropy',
              optimizer = keras.optimizers.Adam(lr=0.0001), 
              metrics = ['accuracy', 'Recall', 'Precision'])

# %%
#Early Stopping

from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor = 'val_loss',
                   mode = 'min',
                   patience = 30,
                   verbose = 1)

# %%
#Model Checkpoint

from keras.callbacks import ModelCheckpoint

mc = ModelCheckpoint('best_vanilla11.h5',
                     monitor = 'val_loss', 
                     mode = 'min',
                     save_best_only = True,
                     verbose = 1)

# %%
# %%time

hist = model.fit(train_data,
                 epochs = 10, 
                 #epochs = 200, 
                 validation_data = valid_data,
                 callbacks = [es, mc],
                 verbose = 1)
# Out:
# Epoch 1/10
# 70/70 [==============================] - 37s 294ms/step - loss: 0.6701 - accuracy: 0.6317 - recall: 0.0204 - precision: 0.2500 - val_loss: 0.5794 - val_accuracy: 0.7300 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.57942, saving model to best_vanilla11.h5
# Epoch 2/10
# 70/70 [==============================] - 20s 291ms/step - loss: 0.6335 - accuracy: 0.6593 - recall: 0.0228 - precision: 0.8551 - val_loss: 0.5568 - val_accuracy: 0.7300 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.57942 to 0.55683, saving model to best_vanilla11.h5
# Epoch 3/10
# 70/70 [==============================] - 20s 289ms/step - loss: 0.5950 - accuracy: 0.6770 - recall: 0.1911 - precision: 0.6510 - val_loss: 0.5320 - val_accuracy: 0.7571 - val_recall: 0.1407 - val_precision: 0.7778
#
# Epoch 00003: val_loss improved from 0.55683 to 0.53204, saving model to best_vanilla11.h5
# Epoch 4/10
# 70/70 [==============================] - 20s 287ms/step - loss: 0.5361 - accuracy: 0.7296 - recall: 0.3758 - precision: 0.7475 - val_loss: 0.5095 - val_accuracy: 0.7748 - val_recall: 0.2412 - val_precision: 0.7619
#
# Epoch 00004: val_loss improved from 0.53204 to 0.50948, saving model to best_vanilla11.h5
# Epoch 5/10
# 70/70 [==============================] - 20s 290ms/step - loss: 0.4686 - accuracy: 0.7729 - recall: 0.4668 - precision: 0.7812 - val_loss: 0.5072 - val_accuracy: 0.7707 - val_recall: 0.5176 - val_precision: 0.5852
#
# Epoch 00005: val_loss improved from 0.50948 to 0.50723, saving model to best_vanilla11.h5
# Epoch 6/10
# 70/70 [==============================] - 20s 289ms/step - loss: 0.4481 - accuracy: 0.8065 - recall: 0.6552 - precision: 0.7722 - val_loss: 0.4682 - val_accuracy: 0.7883 - val_recall: 0.4472 - val_precision: 0.6593
#
# Epoch 00006: val_loss improved from 0.50723 to 0.46816, saving model to best_vanilla11.h5
# Epoch 7/10
# 70/70 [==============================] - 20s 289ms/step - loss: 0.3959 - accuracy: 0.8137 - recall: 0.7027 - precision: 0.7542 - val_loss: 0.4671 - val_accuracy: 0.7883 - val_recall: 0.4623 - val_precision: 0.6525
#
# Epoch 00007: val_loss improved from 0.46816 to 0.46707, saving model to best_vanilla11.h5
# Epoch 8/10
# 70/70 [==============================] - 20s 285ms/step - loss: 0.3624 - accuracy: 0.8571 - recall: 0.7506 - precision: 0.8112 - val_loss: 0.5204 - val_accuracy: 0.7761 - val_recall: 0.3869 - val_precision: 0.6417
#
# Epoch 00008: val_loss did not improve from 0.46707
# Epoch 9/10
# 70/70 [==============================] - 20s 287ms/step - loss: 0.3265 - accuracy: 0.8560 - recall: 0.7286 - precision: 0.8079 - val_loss: 0.5205 - val_accuracy: 0.7558 - val_recall: 0.5930 - val_precision: 0.5438
#
# Epoch 00009: val_loss did not improve from 0.46707
# Epoch 10/10
# 70/70 [==============================] - 20s 287ms/step - loss: 0.3162 - accuracy: 0.8683 - recall: 0.8177 - precision: 0.8172 - val_loss: 0.4979 - val_accuracy: 0.7815 - val_recall: 0.4171 - val_precision: 0.6484
#
# Epoch 00010: val_loss did not improve from 0.46707
# CPU times: user 3min 33s, sys: 4.99 s, total: 3min 38s
# Wall time: 3min 39s

# %% [markdown]
# ### Result

# %%
#전체 epoch 결과 출력
plot_score(hist)

# %%
#best model 불러오기

bestV11 = models.load_model('best_vanilla11.h5')

#best model evaluate(about validation data)

print_score(bestV11, valid_data)

# %%
plot_img(bestV11, valid_data)

# %%
#best model 지정 디렉토리에 저장
model.save('/content/drive/My Drive/인공지능 프로젝트/models/vanilla11.h5')

# !ls -l /content/drive/My\ Drive/Colab\ Notebooks/Project_Test/models

# %% [markdown]
# ***
# <br><br><br><br>
# ***

# %% [markdown]
# ## Test

# %%
#best model evaluate(about test data)

print_score(bestV11, test_data)

# %%
plot_img(bestV11, test_data)
